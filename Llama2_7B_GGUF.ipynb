# %%
# !nvidia-smi
# Out:
# Wed May  6 08:46:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -q llama-cpp-python huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 MB 12.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Hugging Face Login**

# %%
from huggingface_hub import login
login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
from google.colab import userdata
from huggingface_hub import login

token = userdata.get('llama2-colab-hf')
login(token)

# %% [markdown]
# ## Downloading the Llama 2 7B GGUF Model
#
# Downloading the quantized GGUF version of the Llama 2 7B chat model from Hugging Face.

# %%
from huggingface_hub import hf_hub_download

model_path = hf_hub_download(
    repo_id="TheBloke/Llama-2-7B-Chat-GGUF",
    filename="llama-2-7b-chat.Q4_K_M.gguf"
)

print(model_path)
# Out:
# llama-2-7b-chat.Q4_K_M.gguf:   0%|          | 0.00/4.08G [00:00<?, ?B/s]
# /root/.cache/huggingface/hub/models--TheBloke--Llama-2-7B-Chat-GGUF/snapshots/191239b3e26b2882fb562ffccdd1cf0f65402adb/llama-2-7b-chat.Q4_K_M.gguf

# %% [markdown]
# ## Loading the Llama 2 GGUF Model
#
# Loading the quantized GGUF model using llama-cpp-python.

# %%
from llama_cpp import Llama

llm = Llama(
    model_path=model_path,
    n_ctx=2048,
    n_gpu_layers=35
)

print("Model loaded successfully!")
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from /root/.cache/huggingface/hub/models--TheBloke--Llama-2-7B-Chat-GGUF/snapshots/191239b3e26b2882fb562ffccdd1cf0f65402adb/llama-2-7b-chat.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# ...

# %% [markdown]
# ## Generating a Response from Llama 2
#
# Sending a prompt to the Llama 2 GGUF model and generating text output.

# %%
prompt = "Build a Flask API example."

prompt_template = f"""
SYSTEM: You are a helpful, respectful, and honest AI assistant.
Always provide clear, accurate, and beginner-friendly answers.

USER: {prompt}

ASSISTANT:
"""

response = llm(
    prompt_template,
    max_tokens=256,
    temperature=0.5,
    top_p=0.95,
    repeat_penalty=1.2
)

print(response["choices"][0]["text"])
# Out:
# Llama.generate: 40 prefix-match hit, remaining 14 prompt tokens to eval
# llama_perf_context_print:        load time =   12681.55 ms
# llama_perf_context_print: prompt eval time =    3557.81 ms /    14 tokens (  254.13 ms per token,     3.94 tokens per second)
# llama_perf_context_print:        eval time =  157721.95 ms /   255 runs   (  618.52 ms per token,     1.62 tokens per second)
# llama_perf_context_print:       total time =  161565.57 ms /   269 tokens
# llama_perf_context_print:    graphs reused =        253
# Of course! Here is a simple example of building a Flask API:
# ```
# from flask import Flask, jsonify
#
# app = Flask(__name__)
#
# @app.route('/')
# def index():
#     return 'Welcome to my API!'
#
# @app.route('/users', methods=['GET'])
# def get_users():
#     users = [
#         {'id': 1, 'name': 'John Doe'},
#         {'id': 2, 'name': 'Jane Doe'}
#     ]
#     return jsonify(users)
#
# @app.route('/users/<int:user_id>', methods=['GET'])
# def get_user(user_id):
# ...

# %% [markdown]
# # Llama 2 with Hugging Face Transformers
#
# Loading and running the Llama 2 chat model using Transformers, PyTorch, and GPU acceleration in Google Colab.

# %%
# !pip install -q transformers accelerate sentencepiece bitsandbytes langchain
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 6.1 MB/s eta 0:00:00

# %% [markdown]
# ## Importing Required Libraries

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM
from transformers import pipeline

import transformers
import torch
import warnings

warnings.filterwarnings('ignore')

# %%
model = "meta-llama/Llama-2-7b-chat-hf"

# %%
tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %% [markdown]
# ## Loading the Llama 2 Model

# %%
model = AutoModelForCausalLM.from_pretrained(
    model,
    device_map="auto",
    torch_dtype=torch.float16
)

print("Llama 2 model loaded successfully!")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ...
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Llama 2 model loaded successfully!

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Passing `generation_config` together with generation-related arguments=({'top_k', 'do_sample', 'max_length', 'num_return_sequences', 'eos_token_id'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.

# %% [markdown]
# ## Integrating Hugging Face Pipeline with LangChain

# %%
# !pip install -q openai langchain-openai

# %%
from google.colab import userdata
import os

os.environ["PPLX_API_KEY"] = userdata.get("PPLX_API_KEY")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    api_key=os.environ["PPLX_API_KEY"],
    base_url="https://api.perplexity.ai",
    model="sonar"
)

# %%
response = llm.invoke(
    "Explain artificial intelligence in simple words."
)

print(response.content)
# Out:
# # Artificial Intelligence in Simple Words
#
# Artificial intelligence (AI) is **technology that enables computers to do things that normally require human intelligence**.
#
# ## What Can AI Do?
#
# AI systems can:
# - **Learn** from examples and experience
# - **Recognize** patterns (like identifying objects in photos or understanding speech)
# - **Make decisions** on their own
# - **Solve problems** without being told exactly how to do it
# - **Understand and respond** to human language
# - **Provide recommendations** based on data
#
# ## How Does It Work?
#
# Instead of programming a computer with a million rules, you show it many examples. For instance:
# - To teach a computer to recognize dogs, you show it thousands of dog pictures
# - The computer learns the patterns and features that make something a "dog"
# - Then it can identify dogs in new pictures it's never seen before
#
# This learning process is called **machine learning**.
#
# ## Real-World Examples
#
# ...

# %%
response = llm.invoke(
    """
    You are a helpful AI tutor.

    Explain machine learning to a beginner.
    """
)

print(response.content)
# Out:
# # Understanding Machine Learning: A Beginner's Guide
#
# Machine learning is a fascinating field within artificial intelligence that enables computers to **learn from data and make predictions or decisions without being explicitly programmed** for every scenario.
#
# ## The Core Idea
#
# Instead of writing specific instructions for a computer to follow, machine learning works by:
# 1. **Feeding the computer examples** (historical data)
# 2. **Letting it recognize patterns** in that data
# 3. **Using those patterns to make predictions** about new, unseen situations
#
# Think of it like learning to recognize cats: instead of programming every feature a cat has, you show the computer thousands of cat photos, and it learns to identify cats on its own.
#
# ## Main Types of Machine Learning
#
# **Supervised Learning**: You provide labeled examples (like emails marked as "spam" or "not spam"), and the model learns to classify new emails.
#
# ...
